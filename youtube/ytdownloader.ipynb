# %%
import yt_dlp

def list_formats(video_url):
    ydl_opts = {
        'listformats': True,  # Liste tous les formats disponibles
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.extract_info(video_url, download=False)

def download_youtube_video(video_url, format_code):
    ydl_opts = {
        'format': format_code,  # Utilise le format spécifié
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([video_url])

# Demander l'URL de la vidéo à l'utilisateur
video_url = input("Veuillez entrer l'URL complète de la vidéo YouTube : ")

# Lister les formats disponibles
list_formats(video_url)

# Demander le code du format souhaité
format_code = input("Veuillez entrer le code du format à télécharger (ex: 137+140) : ")


try:
    print(f"Téléchargement de la vidéo dans le format {format_code}...")
    download_youtube_video(video_url, format_code)
    print("Téléchargement terminé avec succès.")
except ValueError as e:
    print(e)
# Out:
# [youtube] Extracting URL: https://youtu.be/rsKcvvnc5TM
# [youtube] rsKcvvnc5TM: Downloading webpage
# [youtube] rsKcvvnc5TM: Downloading tv client config
# [youtube] rsKcvvnc5TM: Downloading player b2858d36-main
# [youtube] rsKcvvnc5TM: Downloading tv player API JSON
# [youtube] rsKcvvnc5TM: Downloading ios player API JSON
# [youtube] rsKcvvnc5TM: Downloading m3u8 information
# [info] Available formats for rsKcvvnc5TM:
# ID      EXT   RESOLUTION FPS CH |   FILESIZE   TBR PROTO | VCODEC          VBR ACODEC      ABR ASR MORE INFO
# -------------------------------------------------------------------------------------------------------------------------
# sb3     mhtml 48x27        0    |                  mhtml | images                                  storyboard
# sb2     mhtml 80x45        1    |                  mhtml | images                                  storyboard
# sb1     mhtml 160x90       1    |                  mhtml | images                                  storyboard
# sb0     mhtml 320x180      1    |                  mhtml | images                                  storyboard
# 233     mp4   audio only        |                  m3u8  | audio only          unknown             Default, low
# 234     mp4   audio only        |                  m3u8  | audio only          unknown             Default, high
# 249-drc webm  audio only      2 |    1.37MiB   51k https | audio only          opus        51k 48k low, DRC, webm_dash
# 250-drc webm  audio only      2 |    1.61MiB   60k https | audio only          opus        60k 48k low, DRC, webm_dash
# 249     webm  audio only      2 |    1.37MiB   51k https | audio only          opus        51k 48k low, webm_dash
# 250     webm  audio only      2 |    1.61MiB   60k https | audio only          opus        60k 48k low, webm_dash
# 140-drc m4a   audio only      2 |    3.47MiB  130k https | audio only          mp4a.40.2  130k 44k medium, DRC, m4a_dash
# 251-drc webm  audio only      2 |    2.91MiB  109k https | audio only          opus       109k 48k medium, DRC, webm_dash
# 140     m4a   audio only      2 |    3.47MiB  130k https | audio only          mp4a.40.2  130k 44k medium, m4a_dash
# 251     webm  audio only      2 |    2.91MiB  109k https | audio only          opus       109k 48k medium, webm_dash
# 602     mp4   256x144     13    | ~  2.72MiB  101k m3u8  | vp09.00.10.08  101k video only
# 269     mp4   256x144     25    | ~  4.99MiB  186k m3u8  | avc1.4D400C    186k video only
# 160     mp4   256x144     25    |    1.96MiB   73k https | avc1.4d400c     73k video only          144p, mp4_dash
# 603     mp4   256x144     25    | ~  4.75MiB  177k m3u8  | vp09.00.11.08  177k video only
# 278     webm  256x144     25    |    1.96MiB   73k https | vp9             73k video only          144p, webm_dash
# 229     mp4   426x240     25    | ~  9.22MiB  344k m3u8  | avc1.4D4015    344k video only
# 133     mp4   426x240     25    |    4.28MiB  160k https | avc1.4d4015    160k video only          240p, mp4_dash
# 604     mp4   426x240     25    | ~  7.79MiB  291k m3u8  | vp09.00.20.08  291k video only
# 242     webm  426x240     25    |    3.51MiB  131k https | vp9            131k video only          240p, webm_dash
# 230     mp4   640x360     25    | ~ 21.21MiB  791k m3u8  | avc1.4D401E    791k video only
# 134     mp4   640x360     25    |    8.16MiB  305k https | avc1.4d401e    305k video only          360p, mp4_dash
# 18      mp4   640x360     25  2 |    9.44MiB  352k https | avc1.42001E         mp4a.40.2       22k 360p
# 605     mp4   640x360     25    | ~ 14.23MiB  531k m3u8  | vp09.00.21.08  531k video only
# 243     webm  640x360     25    |    6.04MiB  225k https | vp9            225k video only          360p, webm_dash
# 231     mp4   854x480     25    | ~ 37.00MiB 1380k m3u8  | avc1.4D401E   1380k video only
# 135     mp4   854x480     25    |   17.73MiB  662k https | avc1.4d401e    662k video only          480p, mp4_dash
# 606     mp4   854x480     25    | ~ 21.40MiB  798k m3u8  | vp09.00.30.08  798k video only
# 244     webm  854x480     25    |   10.22MiB  381k https | vp9            381k video only          480p, webm_dash
# 232     mp4   1280x720    25    | ~ 68.38MiB 2549k m3u8  | avc1.64001F   2549k video only
# 136     mp4   1280x720    25    |   36.17MiB 1350k https | avc1.64001f   1350k video only          720p, mp4_dash
# 609     mp4   1280x720    25    | ~ 37.86MiB 1412k m3u8  | vp09.00.31.08 1412k video only
# 247     webm  1280x720    25    |   19.95MiB  745k https | vp9            745k video only          720p, webm_dash
# 270     mp4   1920x1080   25    | ~133.81MiB 4989k m3u8  | avc1.640028   4989k video only
# 137     mp4   1920x1080   25    |   74.32MiB 2775k https | avc1.640028   2775k video only          1080p, mp4_dash
# 614     mp4   1920x1080   25    | ~ 57.99MiB 2162k m3u8  | vp09.00.40.08 2162k video only
# 248     webm  1920x1080   25    |   34.95MiB 1305k https | vp9           1305k video only          1080p, webm_dash
# Téléchargement de la vidéo dans le format 140+137...
# [youtube] Extracting URL: https://youtu.be/rsKcvvnc5TM
# [youtube] rsKcvvnc5TM: Downloading webpage
# [youtube] rsKcvvnc5TM: Downloading tv client config
# [youtube] rsKcvvnc5TM: Downloading player b2858d36-main
# [youtube] rsKcvvnc5TM: Downloading tv player API JSON
# [youtube] rsKcvvnc5TM: Downloading ios player API JSON
# [youtube] rsKcvvnc5TM: Downloading m3u8 information
# [info] rsKcvvnc5TM: Downloading 1 format(s): 140+137
# [download] Destination: Enquête sur la discrimination à l’embauche [rsKcvvnc5TM].f140.m4a
# [download] 100% of    3.47MiB in 00:00:00 at 8.66MiB/s
# [download] Destination: Enquête sur la discrimination à l’embauche [rsKcvvnc5TM].f137.mp4
# [download] 100% of   74.32MiB in 00:00:03 at 22.07MiB/s
# [Merger] Merging formats into "Enquête sur la discrimination à l’embauche [rsKcvvnc5TM].mp4"
# Deleting original file Enquête sur la discrimination à l’embauche [rsKcvvnc5TM].f140.m4a (pass -k to keep)
# Deleting original file Enquête sur la discrimination à l’embauche [rsKcvvnc5TM].f137.mp4 (pass -k to keep)
# Téléchargement terminé avec succès.
